# %% [markdown]
# # Data exploration
# This notebook contains some tests about data import and some data viz tools

# %%
DATA_FOLDER = './data/'
MOVIES_FOLDER = DATA_FOLDER + 'movies_summaries/'
PLOT_SUMMARY_FOLDER = DATA_FOLDER + 'corenlp_plot_summaries'

REPORT_FOLDER = './gen/reports/'
ETHNICITY_FILE = './gen/ethnicities.tsv'

CHARACTERS_FILE = MOVIES_FOLDER + 'character.metadata.tsv'
MOVIES_FILE = MOVIES_FOLDER + 'movie.metadata.tsv'
PLOT_SUMMARIES_FILE = MOVIES_FOLDER + 'plot_summaries.txt'
TROPES_FILE = MOVIES_FOLDER + 'tvtropes.clusters.txt'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# from pandas_profiling import ProfileReport
# %matplotlib inline

# %% [markdown]
# # Characters

# %%
character_columns = ['wiki_movie_id', 'freebase_movie_id', 'm_release_date', 'name', 'a_dob', 'a_gender', 'a_height', 'a_ethnicity_freebase_id', 'a_name', 'a_age_at_release', 'freebase_char/a_map', 'freebase_char_id', 'freebase_a_id']
characters = pd.read_csv(CHARACTERS_FILE, sep='\t', names=character_columns, index_col=False)

characters['m_release_date'] = pd.to_datetime(characters['m_release_date'], format='%Y-%m-%d', errors='coerce')

print(characters.shape)
characters.head()
# Out:
# (450669, 13)
#    wiki_movie_id freebase_movie_id m_release_date                        name  \
# 0         975900         /m/03vyhn     2001-08-24                    Akooshay
# 1         975900         /m/03vyhn     2001-08-24  Lieutenant Melanie Ballard
# 2         975900         /m/03vyhn     2001-08-24         Desolation Williams
# 3         975900         /m/03vyhn     2001-08-24          Sgt Jericho Butler
# 4         975900         /m/03vyhn     2001-08-24             Bashira Kincaid
#
#         a_dob a_gender  a_height a_ethnicity_freebase_id              a_name  \
# 0  1958-08-26        F     1.620                     NaN      Wanda De Jesus
# 1  1974-08-15        F     1.780              /m/044038p  Natasha Henstridge
# 2  1969-06-15        M     1.727                 /m/0x67            Ice Cube
# 3  1967-09-12        M     1.750                     NaN       Jason Statham
# 4  1977-09-25        F     1.650                     NaN         Clea DuVall
#
#    a_age_at_release freebase_char/a_map freebase_char_id freebase_a_id
# 0              42.0          /m/0bgchxw       /m/0bgcj3x    /m/03wcfv7
# 1              27.0           /m/0jys3m       /m/0bgchn4     /m/0346l4
# 2              32.0           /m/0jys3g       /m/0bgchn_    /m/01vw26l
# 3              33.0          /m/02vchl6       /m/0bgchnq     /m/034hyc
# 4              23.0          /m/02vbb3r       /m/0bgchp9     /m/01y9xg

# %%
# generate profiling report
# profile_characters = ProfileReport(characters, title='Characters report')
# profile_characters.to_file(REPORT_FOLDER + "character_report_0.html")

# %% [markdown]
# # Import ethnicities

# %%
ethnicities = pd.read_csv(ETHNICITY_FILE, sep='\t', header=None, names=['freebase_ethnicity_id', 'ethnicity_name'])
ethnicities
# Out:
#     freebase_ethnicity_id              ethnicity_name
# 0                 /m/0x67           African Americans
# 1               /m/064b9n                Omaha people
# 2                /m/041rx               Jewish people
# 3               /m/033tf_             Irish Americans
# 4               /m/04gfy7            Indian Americans
# ..                    ...                         ...
# 425             /m/09r2kh     peoples of the Caucasus
# 426            /m/02ry8mk  Sierra Leone Creole people
# 427             /m/029q52                   Georgians
# 428            /m/026d074                       Goans
# 429             /m/013y54          Han Chinese people
#
# [430 rows x 2 columns]

# %%
characters = pd.merge(left=characters, right=ethnicities, left_on='a_ethnicity_freebase_id', right_on='freebase_ethnicity_id', how='left')
characters = characters.drop(['freebase_ethnicity_id'], axis=1)
characters = characters.rename({'a_ethnicity_freebase_id': 'freebase_ethnicity_id'})
characters
# Out:
#         wiki_movie_id freebase_movie_id m_release_date  \
# 0              975900         /m/03vyhn     2001-08-24
# 1              975900         /m/03vyhn     2001-08-24
# 2              975900         /m/03vyhn     2001-08-24
# 3              975900         /m/03vyhn     2001-08-24
# 4              975900         /m/03vyhn     2001-08-24
# ...               ...               ...            ...
# 450664         913762         /m/03pcrp     1992-05-21
# 450665         913762         /m/03pcrp     1992-05-21
# 450666       28308153        /m/0cp05t9     1957-01-01
# 450667       28308153        /m/0cp05t9     1957-01-01
# 450668       28308153        /m/0cp05t9     1957-01-01
#
#                               name       a_dob a_gender  a_height  \
# 0                         Akooshay  1958-08-26        F     1.620
# 1       Lieutenant Melanie Ballard  1974-08-15        F     1.780
# 2              Desolation Williams  1969-06-15        M     1.727
# 3               Sgt Jericho Butler  1967-09-12        M     1.750
# 4                  Bashira Kincaid  1977-09-25        F     1.650
# ...                            ...         ...      ...       ...
# 450664                      Elensh     1970-05        F       NaN
# 450665                      Hibiki  1965-04-12        M       NaN
# 450666                         NaN  1941-11-18        M     1.730
# 450667                         NaN         NaN      NaN       NaN
# 450668                         NaN         NaN      NaN       NaN
#
#        a_ethnicity_freebase_id              a_name  a_age_at_release  \
# 0                          NaN      Wanda De Jesus              42.0
# 1                   /m/044038p  Natasha Henstridge              27.0
# 2                      /m/0x67            Ice Cube              32.0
# 3                          NaN       Jason Statham              33.0
# 4                          NaN         Clea DuVall              23.0
# ...                        ...                 ...               ...
# 450664                     NaN  Dorothy Elias-Fahn               NaN
# 450665                     NaN       Jonathan Fahn              27.0
# 450666               /m/02w7gg      David Hemmings              15.0
# 450667                     NaN    Roberta Paterson               NaN
# 450668                     NaN         John Rogers               NaN
#
#        freebase_char/a_map freebase_char_id freebase_a_id     ethnicity_name
# 0               /m/0bgchxw       /m/0bgcj3x    /m/03wcfv7                NaN
# 1                /m/0jys3m       /m/0bgchn4     /m/0346l4                NaN
# 2                /m/0jys3g       /m/0bgchn_    /m/01vw26l  African Americans
# 3               /m/02vchl6       /m/0bgchnq     /m/034hyc                NaN
# 4               /m/02vbb3r       /m/0bgchp9     /m/01y9xg                NaN
# ...                    ...              ...           ...                ...
# 450664          /m/0kr406c       /m/0kr406h     /m/0b_vcv                NaN
# 450665          /m/0kr405_       /m/0kr4090     /m/0bx7_j                NaN
# 450666          /m/0g8ngmc              NaN     /m/022g44     English people
# 450667          /m/0g8ngmj              NaN    /m/0g8ngmm                NaN
# 450668          /m/0g8ngmw              NaN    /m/0btz19d                NaN
#
# [450669 rows x 14 columns]

# %% [markdown]
# # Import tvtropes
# Import tv tropes to assign a trope to characters

# %%
tropes = pd.read_csv(TROPES_FILE, sep='\t', header=None, names=['trope', 'props'])
tropes
# Out:
#                        trope  \
# 0    absent_minded_professor
# 1    absent_minded_professor
# 2    absent_minded_professor
# 3    absent_minded_professor
# 4    absent_minded_professor
# ..                       ...
# 496                young_gun
# 497                young_gun
# 498                young_gun
# 499                young_gun
# 500                young_gun
#
#                                                  props
# 0    {"char": "Professor Philip Brainard", "movie":...
# 1    {"char": "Professor Keenbean", "movie": "Richi...
# 2    {"char": "Dr. Reinhardt Lane", "movie": "The S...
# 3    {"char": "Dr. Harold Medford", "movie": "Them!...
# 4    {"char": "Daniel Jackson", "movie": "Stargate"...
# ..                                                 ...
# 496  {"char": "Morgan Earp", "movie": "Tombstone", ...
# 497  {"char": "Colorado Ryan", "movie": "Rio Bravo"...
# 498  {"char": "Tom Sawyer", "movie": "The League of...
# 499  {"char": "William H. 'Billy the Kid' Bonney", ...
# 500  {"char": "Jake", "movie": "Silverado", "id": "...
#
# [501 rows x 2 columns]

# %%
def split_tropes_props(x):
    res = {'trope': x['trope']}
    res.update(ast.literal_eval(x['props']))
    return res

tropes = tropes.apply(split_tropes_props, axis=1, result_type='expand')
tropes = tropes.rename(columns={'id': 'freebase_char/a_map'})
tropes
# Out:
#                        trope                               char  \
# 0    absent_minded_professor          Professor Philip Brainard
# 1    absent_minded_professor                 Professor Keenbean
# 2    absent_minded_professor                 Dr. Reinhardt Lane
# 3    absent_minded_professor                 Dr. Harold Medford
# 4    absent_minded_professor                     Daniel Jackson
# ..                       ...                                ...
# 496                young_gun                        Morgan Earp
# 497                young_gun                      Colorado Ryan
# 498                young_gun                         Tom Sawyer
# 499                young_gun  William H. 'Billy the Kid' Bonney
# 500                young_gun                               Jake
#
#                                      movie freebase_char/a_map  \
# 0                                  Flubber           /m/0jy9q0
# 1                              Richie Rich          /m/02vchl3
# 2                               The Shadow           /m/0k6fkc
# 3                                    Them!           /m/0k6_br
# 4                                 Stargate           /m/0k3rhh
# ..                                     ...                 ...
# 496                              Tombstone           /m/0k776f
# 497                              Rio Bravo           /m/0k2kqg
# 498  The League of Extraordinary Gentlemen           /m/0k5nsh
# 499                          Young Guns II          /m/03lrjk0
# 500                              Silverado           /m/0k39jj
#
#                actor
# 0     Robin Williams
# 1    Michael McShane
# 2       Ian McKellen
# 3       Edmund Gwenn
# 4       James Spader
# ..               ...
# 496      Bill Paxton
# 497     Ricky Nelson
# 498       Shane West
# 499   Emilio Estevez
# 500    Kevin Costner
#
# [501 rows x 5 columns]

# %%
# problem: we only have 501 characters tropes
characters_tropes = pd.merge(left=characters, right=tropes, on='freebase_char/a_map', how='inner')
characters_tropes
# Out:
#      wiki_movie_id freebase_movie_id m_release_date              name  \
# 0           196176         /m/01bwgr     1971-11-03      David Sumner
# 1          1157158         /m/04c13q     2002-03-29     Sheldon Mopes
# 2           504242         /m/02j9_2     2005-08-22      Mr. Universe
# 3          6917005         /m/0gwypk     2003-02-16       Harold Hill
# 4          6917005         /m/0gwypk     2003-02-16       Harold Hill
# ..             ...               ...            ...               ...
# 496         101954          /m/0pv3x     1996-11-06  Geoffrey Clifton
# 497        9513043        /m/02ph9tm     2008-06-06             Zohan
# 498          52549          /m/0dtfn     1977-05-25          Han Solo
# 499          52549          /m/0dtfn     1977-05-25          Han Solo
# 500          43452          /m/0bx0l     1962-12-10    T. E. Lawrence
#
#           a_dob a_gender  a_height a_ethnicity_freebase_id             a_name  \
# 0    1937-08-08        M      1.66                /m/041rx     Dustin Hoffman
# 1    1969-08-18        M      1.83                     NaN      Edward Norton
# 2    1978-05-15        M      1.68                /m/041rx    David Krumholtz
# 3    1962-03-21        M      1.73                /m/041rx  Matthew Broderick
# 4    1962-03-21        M      1.73                /m/041rx  Matthew Broderick
# ..          ...      ...       ...                     ...                ...
# 496  1960-09-10        M      1.87                /m/0d7wh        Colin Firth
# 497  1966-09-09        M      1.78                /m/041rx       Adam Sandler
# 498  1942-07-13        M      1.85               /m/01qhm_      Harrison Ford
# 499  1942-07-13        M      1.85               /m/01qhm_      Harrison Ford
# 500  1932-08-02        M      1.91               /m/02g7sp      Peter O'Toole
#
#      a_age_at_release freebase_char/a_map freebase_char_id freebase_a_id  \
# 0                34.0           /m/0k3v65       /m/0ch916z      /m/0bl2g
# 1                32.0           /m/0jx3b8       /m/0gy99_8     /m/01515w
# 2                27.0           /m/0k31lb       /m/02sgjdt     /m/05cx7x
# 3                40.0          /m/04hv61w       /m/09j606t    /m/01vlj1g
# 4                40.0          /m/04hv61w       /m/09j606t    /m/01vlj1g
# ..                ...                 ...              ...           ...
# 496              36.0           /m/0k4_tz       /m/0c0fwm8    /m/03f1zdw
# 497              41.0          /m/03hqx35       /m/0cb03np      /m/0pz91
# 498              34.0           /m/0k3r1_         /m/0fjn8      /m/0c0k1
# 499              34.0           /m/0k3r1_         /m/0fjn8      /m/0c0k1
# 500              30.0           /m/0j_tdt       /m/02nw8h0      /m/0h0jz
#
#                        ethnicity_name              trope              char  \
# 0                       Jewish people      tranquil_fury      David Sumner
# 1                                 NaN     granola_person     Sheldon Mopes
# 2                       Jewish people     playful_hacker      Mr. Universe
# 3                       Jewish people            charmer       Harold Hill
# 4                       Jewish people     loveable_rogue       Harold Hill
# ..                                ...                ...               ...
# 496                    British people  crazy_jealous_guy  Geoffrey Clifton
# 497                     Jewish people       warrior_poet             Zohan
# 498                  German Americans            charmer          Han Solo
# 499                  German Americans     loveable_rogue          Han Solo
# 500  Irish migration to Great Britain       warrior_poet    T. E. Lawrence
#
#                                 movie              actor
# 0                          Straw Dogs     Dustin Hoffman
# 1                    Death to Smoochy      Edward Norton
# 2                            Serenity    David Krumholtz
# 3                       The Music Man  Matthew Broderick
# 4                       The Music Man  Matthew Broderick
# ..                                ...                ...
# 496               The English Patient        Colin Firth
# 497     You Don't Mess with the Zohan       Adam Sandler
# 498  Star Wars Episode IV: A New Hope      Harrison Ford
# 499  Star Wars Episode IV: A New Hope      Harrison Ford
# 500                Lawrence of Arabia      Peter O'Toole
#
# [501 rows x 18 columns]

# %% [markdown]
# # Movies

# %%
movies_columns = ['wiki_movie_id', 'freebase_movie_id', 'name', 'release_date', 'box_office_revenue', 'runtime', 'languages', 'countries', 'genres']
movies = pd.read_csv(MOVIES_FILE, sep='\t', names=movies_columns)

print(movies.shape)
movies.head()
# Out:
# (81741, 9)
#    wiki_movie_id freebase_movie_id  \
# 0         975900         /m/03vyhn
# 1        3196793         /m/08yl5d
# 2       28463795        /m/0crgdbh
# 3        9363483        /m/0285_cd
# 4         261236         /m/01mrr1
#
#                                                 name release_date  \
# 0                                     Ghosts of Mars   2001-08-24
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                        Brun bitter         1988
# 3                                   White Of The Eye         1987
# 4                                  A Woman in Flames         1983
#
#    box_office_revenue  runtime                           languages  \
# 0          14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1                 NaN     95.0  {"/m/02h40lc": "English Language"}
# 2                 NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3                 NaN    110.0  {"/m/02h40lc": "English Language"}
# 4                 NaN    106.0   {"/m/04306rv": "German Language"}
#
#                                    countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                               genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}

# %%
# generate profiling report
# profile_movies = ProfileReport(movies, title='Movies report')
# profile_movies.to_file(REPORT_FOLDER + "movies_report_0.html")

# %%
# Clean dates
# Remember that one movie contains 1010 date. We need to check what to do with it. Movie : Hunting Season, changes by hand at the moment
# Note: use .dt.date to recover the date only (not the datetime part)
print("Number of nan movies release dates: ", movies['release_date'].isna().sum())
movies['release_date'] = pd.to_datetime(movies['release_date'], format='%Y-%m-%d', errors='coerce')
movies.head()
# Out:
# Number of nan movies release dates:  6902
#    wiki_movie_id freebase_movie_id  \
# 0         975900         /m/03vyhn
# 1        3196793         /m/08yl5d
# 2       28463795        /m/0crgdbh
# 3        9363483        /m/0285_cd
# 4         261236         /m/01mrr1
#
#                                                 name release_date  \
# 0                                     Ghosts of Mars   2001-08-24
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                        Brun bitter   1988-01-01
# 3                                   White Of The Eye   1987-01-01
# 4                                  A Woman in Flames   1983-01-01
#
#    box_office_revenue  runtime                           languages  \
# 0          14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1                 NaN     95.0  {"/m/02h40lc": "English Language"}
# 2                 NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3                 NaN    110.0  {"/m/02h40lc": "English Language"}
# 4                 NaN    106.0   {"/m/04306rv": "German Language"}
#
#                                    countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                               genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}

# %%
print("Number of movies with box office revenue indicated: {} ({:.2%})".format(movies.shape[0] - movies['box_office_revenue'].isna().sum(), (movies.shape[0] - movies['box_office_revenue'].isna().sum())/movies.shape[0]))

# keep only movies with box office revenue
movies_without_na = movies[movies['box_office_revenue'].notna()]
print(movies_without_na.shape)
# Out:
# Number of movies with box office revenue indicated: 8401 (10.28%)
# (8401, 9)

# %%
movies_by_year = movies.groupby(movies['release_date'].dt.year)['release_date'].count()
movies_by_year_without_na = movies_without_na.groupby(movies_without_na['release_date'].dt.year)['release_date'].count()

# plot values
fig, ax = plt.subplots(1, 2, figsize=(20, 5))
ax[0].set_title('Movies by year')
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Number of movies')
ax[0].bar(movies_by_year.index, movies_by_year.values)
# ax[0] = plt.bar(x=movies_by_year.index, y=movies_by_year.values, ax=ax[0], color='lightblue')
# ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=90)

ax[1].set_title('Movies by year (without NA)')
ax[1].set_xlabel('Year')
ax[1].set_ylabel('Number of movies')
ax[1].bar(movies_by_year_without_na.index, movies_by_year_without_na.values)
plt.show()

# %%
## Get box office revenue by year
movies = movies_without_na
movies['box_office_revenue'] = movies['box_office_revenue'].astype(int)

# %%
def sort_by_box_office_revenue(df, k=10):
    return df.sort_values(by='box_office_revenue', ascending=False).head(k)

movies_by_year = movies.groupby(movies['release_date'].dt.year).apply(sort_by_box_office_revenue)
movies_by_year
# Out:
#                     wiki_movie_id freebase_movie_id  \
# release_date
# 1897.0       48417       28703057        /m/0czdh_n
# 1914.0       49852       15130915        /m/03hjhh9
#              53319       15340505        /m/03m5kln
#              50991        1762869         /m/05tz4w
#              1026        14613957        /m/03gqmqv
# ...                           ...               ...
# 2012.0       78373       31186339        /m/0gkz15s
#              22008       13049327        /m/0661m4p
#              13702       16839300        /m/0407yfx
#              51913       31201599        /m/0gj9tn5
#              12076       31775043        /m/0gd0c7x
#
#                                              name release_date  \
# release_date
# 1897.0       48417  The Corbett-Fitzsimmons Fight   1897-05-22
# 1914.0       49852     The Million Dollar Mystery   1914-06-22
#              53319             Neptune's Daughter   1914-04-25
#              50991                  The Squaw Man   1914-02-15
#              1026              Rose of the Rancho   1914-11-15
# ...                                           ...          ...
# 2012.0       78373               The Hunger Games   2012-03-12
#              22008                 Men in Black 3   2012-05-14
#              13702                          Brave   2012-06-10
#              51913                            Ted   2012-06-29
#              12076                     Prometheus   2012-05-30
#
#                     box_office_revenue  runtime  \
# release_date
# 1897.0       48417              100000      NaN
# 1914.0       49852             1500000      NaN
#              53319             1000000      NaN
#              50991              244700     74.0
#              1026                87028      NaN
# ...                                ...      ...
# 2012.0       78373           686533290    142.0
#              22008           624026776    103.0
#              13702           531957538     95.0
#              51913           488965740    106.0
#              12076           402480000    124.0
#
#                                                             languages  \
# release_date
# 1897.0       48417                                                 {}
# 1914.0       49852                 {"/m/02h40lc": "English Language"}
#              53319                 {"/m/02h40lc": "English Language"}
#              50991  {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
#              1026   {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# ...                                                               ...
# 2012.0       78373                 {"/m/02h40lc": "English Language"}
#              22008                 {"/m/02h40lc": "English Language"}
#              13702                 {"/m/02h40lc": "English Language"}
#              51913                 {"/m/02h40lc": "English Language"}
#              12076  {"/m/01ncmg": "Gaelic", "/m/02h40lc": "English...
#
#                                                     countries  \
# release_date
# 1897.0       48417                                         {}
# 1914.0       49852  {"/m/09c7w0": "United States of America"}
#              53319  {"/m/09c7w0": "United States of America"}
#              50991  {"/m/09c7w0": "United States of America"}
#              1026   {"/m/09c7w0": "United States of America"}
# ...                                                       ...
# 2012.0       78373  {"/m/09c7w0": "United States of America"}
#              22008  {"/m/09c7w0": "United States of America"}
#              13702  {"/m/09c7w0": "United States of America"}
#              51913  {"/m/09c7w0": "United States of America"}
#              12076  {"/m/09c7w0": "United States of America"}
#
#                                                                genres
# release_date
# 1897.0       48417                           {"/m/01z02hx": "Sports"}
# 1914.0       49852  {"/m/06ppq": "Silent film", "/m/0219x_": "Indi...
#              53319  {"/m/06ppq": "Silent film", "/m/0219x_": "Indi...
#              50991  {"/m/06ppq": "Silent film", "/m/0hfjk": "Weste...
#              1026   {"/m/0hfjk": "Western", "/m/06ppq": "Silent fi...
# ...                                                               ...
# 2012.0       78373  {"/m/03btsm8": "Action/Adventure", "/m/06n90":...
#              22008  {"/m/06n90": "Science Fiction", "/m/02kdv5l": ...
#              13702  {"/m/03k9fj": "Adventure", "/m/01zhp": "Comput...
#              51913                             {"/m/01z4y": "Comedy"}
#              12076  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
#
# [860 rows x 9 columns]

# %% [markdown]
# # Import summaries

# %%
summaries = pd.read_csv(PLOT_SUMMARIES_FILE, sep='\t', index_col=0, names=['plot'])
summaries.index.name = 'wiki_movie_id'

# %%
# Movies and characters
# Here, we do a left join in order to keep all characters
df = pd.merge(left=characters, right=movies, on='wiki_movie_id', how='left', suffixes=('_m', '_c'))
duplicate_columns = ['freebase_movie_id_c', 'm_release_date']
df = df.drop(duplicate_columns, axis=1)
df = df.rename(columns={'freebase_movie_id_m': 'freebase_movie_id'})

# Merge movies, characters and summaries
# Here, we do do a left join too, because we may want to have info relating the plots and the character, even without having info on the movie
# However, if other information are required, it could be better to join movies and summaries before merging with characters, in order to select only plots for which we have movies info
df = pd.merge(left=df, right=summaries, on='wiki_movie_id', how='left')
df
# Out:
#         wiki_movie_id freebase_movie_id                      name_m  \
# 0              975900         /m/03vyhn                    Akooshay
# 1              975900         /m/03vyhn  Lieutenant Melanie Ballard
# 2              975900         /m/03vyhn         Desolation Williams
# 3              975900         /m/03vyhn          Sgt Jericho Butler
# 4              975900         /m/03vyhn             Bashira Kincaid
# ...               ...               ...                         ...
# 450664         913762         /m/03pcrp                      Elensh
# 450665         913762         /m/03pcrp                      Hibiki
# 450666       28308153        /m/0cp05t9                         NaN
# 450667       28308153        /m/0cp05t9                         NaN
# 450668       28308153        /m/0cp05t9                         NaN
#
#              a_dob a_gender  a_height a_ethnicity_freebase_id  \
# 0       1958-08-26        F     1.620                     NaN
# 1       1974-08-15        F     1.780              /m/044038p
# 2       1969-06-15        M     1.727                 /m/0x67
# 3       1967-09-12        M     1.750                     NaN
# 4       1977-09-25        F     1.650                     NaN
# ...            ...      ...       ...                     ...
# 450664     1970-05        F       NaN                     NaN
# 450665  1965-04-12        M       NaN                     NaN
# 450666  1941-11-18        M     1.730               /m/02w7gg
# 450667         NaN      NaN       NaN                     NaN
# 450668         NaN      NaN       NaN                     NaN
#
#                     a_name  a_age_at_release freebase_char/a_map  \
# 0           Wanda De Jesus              42.0          /m/0bgchxw
# 1       Natasha Henstridge              27.0           /m/0jys3m
# 2                 Ice Cube              32.0           /m/0jys3g
# 3            Jason Statham              33.0          /m/02vchl6
# 4              Clea DuVall              23.0          /m/02vbb3r
# ...                    ...               ...                 ...
# 450664  Dorothy Elias-Fahn               NaN          /m/0kr406c
# 450665       Jonathan Fahn              27.0          /m/0kr405_
# 450666      David Hemmings              15.0          /m/0g8ngmc
# 450667    Roberta Paterson               NaN          /m/0g8ngmj
# 450668         John Rogers               NaN          /m/0g8ngmw
#
#        freebase_char_id freebase_a_id     ethnicity_name          name_c  \
# 0            /m/0bgcj3x    /m/03wcfv7                NaN  Ghosts of Mars
# 1            /m/0bgchn4     /m/0346l4                NaN  Ghosts of Mars
# 2            /m/0bgchn_    /m/01vw26l  African Americans  Ghosts of Mars
# 3            /m/0bgchnq     /m/034hyc                NaN  Ghosts of Mars
# 4            /m/0bgchp9     /m/01y9xg                NaN  Ghosts of Mars
# ...                 ...           ...                ...             ...
# 450664       /m/0kr406h     /m/0b_vcv                NaN             NaN
# 450665       /m/0kr4090     /m/0bx7_j                NaN             NaN
# 450666              NaN     /m/022g44     English people             NaN
# 450667              NaN    /m/0g8ngmm                NaN             NaN
# 450668              NaN    /m/0btz19d                NaN             NaN
#
#        release_date  box_office_revenue  runtime  \
# 0        2001-08-24          14010832.0     98.0
# 1        2001-08-24          14010832.0     98.0
# 2        2001-08-24          14010832.0     98.0
# 3        2001-08-24          14010832.0     98.0
# 4        2001-08-24          14010832.0     98.0
# ...             ...                 ...      ...
# 450664          NaT                 NaN      NaN
# 450665          NaT                 NaN      NaN
# 450666          NaT                 NaN      NaN
# 450667          NaT                 NaN      NaN
# 450668          NaT                 NaN      NaN
#
#                                  languages  \
# 0       {"/m/02h40lc": "English Language"}
# 1       {"/m/02h40lc": "English Language"}
# 2       {"/m/02h40lc": "English Language"}
# 3       {"/m/02h40lc": "English Language"}
# 4       {"/m/02h40lc": "English Language"}
# ...                                    ...
# 450664                                 NaN
# 450665                                 NaN
# 450666                                 NaN
# 450667                                 NaN
# 450668                                 NaN
#
#                                         countries  \
# 0       {"/m/09c7w0": "United States of America"}
# 1       {"/m/09c7w0": "United States of America"}
# 2       {"/m/09c7w0": "United States of America"}
# 3       {"/m/09c7w0": "United States of America"}
# 4       {"/m/09c7w0": "United States of America"}
# ...                                           ...
# 450664                                        NaN
# 450665                                        NaN
# 450666                                        NaN
# 450667                                        NaN
# 450668                                        NaN
#
#                                                    genres  \
# 0       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 2       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 3       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 4       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# ...                                                   ...
# 450664                                                NaN
# 450665                                                NaN
# 450666                                                NaN
# 450667                                                NaN
# 450668                                                NaN
#
#                                                      plot
# 0       Set in the second half of the 22nd century, th...
# 1       Set in the second half of the 22nd century, th...
# 2       Set in the second half of the 22nd century, th...
# 3       Set in the second half of the 22nd century, th...
# 4       Set in the second half of the 22nd century, th...
# ...                                                   ...
# 450664  The story takes place in the year 2092,The Sup...
# 450665  The story takes place in the year 2092,The Sup...
# 450666                                                NaN
# 450667                                                NaN
# 450668                                                NaN
#
# [450669 rows x 21 columns]

# %% [markdown]
# # Analyse tv tropes

# %%
# plot the number of characters of each ethnicity
fig, ax = plt.subplots(figsize=(20, 5))
plt.title('Number of characters by ethnicity')
sns.countplot(x=characters_tropes['ethnicity_name'], color='lightblue', ax=ax)
ax.set_xlabel('Ethnicity')
plt.xticks(rotation=90)
plt.grid(axis='y') #{'major', 'minor', 'both'}
plt.show()

# %%
# Get the ethnicities with more than one character
ethnicity_count = characters.groupby('ethnicity_name')['ethnicity_name'].count()
ethnicity_count = ethnicity_count[ethnicity_count > 100]
print(ethnicity_count.min())
print(ethnicity_count.shape)
# ethnicity_count
fig, ax = plt.subplots(figsize=(20, 5))
plt.title('Number of characters by ethnicity')

sns.barplot(x=ethnicity_count.index, y=ethnicity_count, color='lightblue', ax=ax)
ax.set_xlabel('Ethnicity')
plt.xticks(rotation=90)
plt.grid(axis='y') #{'major', 'minor', 'both'}
plt.show()
# Out:
# 101
# (114,)

# %% [markdown]
# ## Display top 10 ethnicities by decade

# %%
import matplotlib
# count instances of ethnicities for each year
df1 = characters[~characters['ethnicity_name'].isna()]

# from https://stackoverflow.com/questions/17764619/pandas-dataframe-group-year-index-by-decade
ethnicity_count = df1.groupby([df1['m_release_date'].dt.year // 10 * 10, df1['ethnicity_name']]).count()[['wiki_movie_id']]
# gen a "pretty" and usable dataset
ethnicity_count = ethnicity_count.rename(columns={'wiki_movie_id': 'count'})
ethnicity_count = ethnicity_count.reset_index() # level=1
ethnicity_count = ethnicity_count.rename(columns={'m_release_date': 'm_release_decade'})

# get top k ethnicites for each decade
top_k = 10
decades = ethnicity_count['m_release_decade'].unique()

fig, ax = plt.subplots(3, 4, figsize=(20, 10), sharey=True)
ax = ax.flatten()

for i, decade in enumerate(decades[1:]): # TODO the 1890 movies are not displayed
    # get top k ethnicites
    df_top_k = ethnicity_count[ethnicity_count['m_release_decade'] == decade].sort_values(by='count', ascending=False).head(top_k)

    # percentage of the top k
    total = df_top_k['count'].sum()
    df_top_k['percentage'] = df_top_k['count'].apply(lambda x: x / total * 100)

    # plot distribution
    sns.barplot(x=df_top_k['ethnicity_name'], y=df_top_k['percentage'], ax=ax[i])

    ax[i].set_title('{}s'.format(int(decade)))
    ax[i].set_xlabel('Ethnicity')
    ax[i].set_xlabel('Percentage')

    # pretty label display
    patches = [matplotlib.patches.Patch(color=sns.color_palette()[j], label=t) for j,t in enumerate(t.get_text() for t in ax[i].get_xticklabels())]
    ax[i].legend(handles=patches, loc="upper right") 

    # before legend
    # sns.barplot(x=df_top_k['ethnicity_name'], y=df_top_k['percentage'], color='lightblue', ax=ax[i])
    # ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=90) 
    ax[i].tick_params(bottom=False)

plt.tight_layout()
plt.show()

# TODO same color for the same ethnicity in all plots

# %%
import matplotlib
# count instances of ethnicities for each year
df1 = characters[~characters['ethnicity_name'].isna()]

# from https://stackoverflow.com/questions/17764619/pandas-dataframe-group-year-index-by-decade
ethnicity_count = df1.groupby([df1['m_release_date'].dt.year // 10 * 10, df1['ethnicity_name']]).count()[['wiki_movie_id']]
# gen a "pretty" and usable dataset
ethnicity_count = ethnicity_count.rename(columns={'wiki_movie_id': 'count'})
ethnicity_count = ethnicity_count.reset_index() # level=1
ethnicity_count = ethnicity_count.rename(columns={'m_release_date': 'm_release_decade'})

# get top k ethnicites for each decade
top_k = 10
decades = ethnicity_count['m_release_decade'].unique()

fig, ax = plt.subplots(3, 4, figsize=(20, 10), sharey=True)
ax = ax.flatten()

for i, decade in enumerate(decades[1:]): # TODO the 1890 movies are not displayed
    # get top k ethnicites
    df_top_k = ethnicity_count[ethnicity_count['m_release_decade'] == decade].sort_values(by='count', ascending=False).head(top_k)

    # percentage of the top k
    total = df_top_k['count'].sum()
    df_top_k['percentage'] = df_top_k['count'].apply(lambda x: x / total * 100)

    # plot distribution
    sns.barplot(x=df_top_k['ethnicity_name'], y=df_top_k['percentage'], color='lightblue', ax=ax[i])

    ax[i].set_title('{}s'.format(int(decade)))
    ax[i].set_xlabel('Ethnicity')
    ax[i].set_xlabel('Percentage')

    # pretty label display
    patches = [matplotlib.patches.Patch(color=sns.color_palette()[j], label=t) for j,t in enumerate(t.get_text() for t in ax[i].get_xticklabels())]
    ax[i].legend(handles=patches, loc="upper right") 

    # before legend
    ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=90) 

plt.tight_layout()
plt.show()

# TODO same color for the same ethnicity in all plots

# %%
# correction of the name of two columns of df (name_m and name_c have been falsely switched)
df = df.rename(columns={'name_m': 'char_name', 'name_c': 'movie_name', 'ethnicity_name': 'a_ethnicity'})
# change order of columns
df = df[['wiki_movie_id','freebase_movie_id','movie_name','release_date','box_office_revenue','runtime','genres','languages','countries','plot','char_name','a_name','a_gender','a_ethnicity','a_dob','a_age_at_release','a_height','freebase_char/a_map','freebase_char_id','freebase_a_id','a_ethnicity_freebase_id']]
# print all columns and more rows
pd.set_option('display.max_columns', None)
df
# Out:
#         wiki_movie_id freebase_movie_id      movie_name release_date  \
# 0              975900         /m/03vyhn  Ghosts of Mars   2001-08-24
# 1              975900         /m/03vyhn  Ghosts of Mars   2001-08-24
# 2              975900         /m/03vyhn  Ghosts of Mars   2001-08-24
# 3              975900         /m/03vyhn  Ghosts of Mars   2001-08-24
# 4              975900         /m/03vyhn  Ghosts of Mars   2001-08-24
# ...               ...               ...             ...          ...
# 450664         913762         /m/03pcrp             NaN          NaT
# 450665         913762         /m/03pcrp             NaN          NaT
# 450666       28308153        /m/0cp05t9             NaN          NaT
# 450667       28308153        /m/0cp05t9             NaN          NaT
# 450668       28308153        /m/0cp05t9             NaN          NaT
#
#         box_office_revenue  runtime  \
# 0               14010832.0     98.0
# 1               14010832.0     98.0
# 2               14010832.0     98.0
# 3               14010832.0     98.0
# 4               14010832.0     98.0
# ...                    ...      ...
# 450664                 NaN      NaN
# 450665                 NaN      NaN
# 450666                 NaN      NaN
# 450667                 NaN      NaN
# 450668                 NaN      NaN
#
#                                                    genres  \
# 0       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 2       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 3       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 4       {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# ...                                                   ...
# 450664                                                NaN
# 450665                                                NaN
# 450666                                                NaN
# 450667                                                NaN
# 450668                                                NaN
#
#                                  languages  \
# 0       {"/m/02h40lc": "English Language"}
# 1       {"/m/02h40lc": "English Language"}
# 2       {"/m/02h40lc": "English Language"}
# 3       {"/m/02h40lc": "English Language"}
# 4       {"/m/02h40lc": "English Language"}
# ...                                    ...
# 450664                                 NaN
# 450665                                 NaN
# 450666                                 NaN
# 450667                                 NaN
# 450668                                 NaN
#
#                                         countries  \
# 0       {"/m/09c7w0": "United States of America"}
# 1       {"/m/09c7w0": "United States of America"}
# 2       {"/m/09c7w0": "United States of America"}
# 3       {"/m/09c7w0": "United States of America"}
# 4       {"/m/09c7w0": "United States of America"}
# ...                                           ...
# 450664                                        NaN
# 450665                                        NaN
# 450666                                        NaN
# 450667                                        NaN
# 450668                                        NaN
#
#                                                      plot  \
# 0       Set in the second half of the 22nd century, th...
# 1       Set in the second half of the 22nd century, th...
# 2       Set in the second half of the 22nd century, th...
# 3       Set in the second half of the 22nd century, th...
# 4       Set in the second half of the 22nd century, th...
# ...                                                   ...
# 450664  The story takes place in the year 2092,The Sup...
# 450665  The story takes place in the year 2092,The Sup...
# 450666                                                NaN
# 450667                                                NaN
# 450668                                                NaN
#
#                          char_name              a_name a_gender  \
# 0                         Akooshay      Wanda De Jesus        F
# 1       Lieutenant Melanie Ballard  Natasha Henstridge        F
# 2              Desolation Williams            Ice Cube        M
# 3               Sgt Jericho Butler       Jason Statham        M
# 4                  Bashira Kincaid         Clea DuVall        F
# ...                            ...                 ...      ...
# 450664                      Elensh  Dorothy Elias-Fahn        F
# 450665                      Hibiki       Jonathan Fahn        M
# 450666                         NaN      David Hemmings        M
# 450667                         NaN    Roberta Paterson      NaN
# 450668                         NaN         John Rogers      NaN
#
#               a_ethnicity       a_dob  a_age_at_release  a_height  \
# 0                     NaN  1958-08-26              42.0     1.620
# 1                     NaN  1974-08-15              27.0     1.780
# 2       African Americans  1969-06-15              32.0     1.727
# 3                     NaN  1967-09-12              33.0     1.750
# 4                     NaN  1977-09-25              23.0     1.650
# ...                   ...         ...               ...       ...
# 450664                NaN     1970-05               NaN       NaN
# 450665                NaN  1965-04-12              27.0       NaN
# 450666     English people  1941-11-18              15.0     1.730
# 450667                NaN         NaN               NaN       NaN
# 450668                NaN         NaN               NaN       NaN
#
#        freebase_char/a_map freebase_char_id freebase_a_id  \
# 0               /m/0bgchxw       /m/0bgcj3x    /m/03wcfv7
# 1                /m/0jys3m       /m/0bgchn4     /m/0346l4
# 2                /m/0jys3g       /m/0bgchn_    /m/01vw26l
# 3               /m/02vchl6       /m/0bgchnq     /m/034hyc
# 4               /m/02vbb3r       /m/0bgchp9     /m/01y9xg
# ...                    ...              ...           ...
# 450664          /m/0kr406c       /m/0kr406h     /m/0b_vcv
# 450665          /m/0kr405_       /m/0kr4090     /m/0bx7_j
# 450666          /m/0g8ngmc              NaN     /m/022g44
# 450667          /m/0g8ngmj              NaN    /m/0g8ngmm
# 450668          /m/0g8ngmw              NaN    /m/0btz19d
#
#        a_ethnicity_freebase_id
# 0                          NaN
# 1                   /m/044038p
# 2                      /m/0x67
# 3                          NaN
# 4                          NaN
# ...                        ...
# 450664                     NaN
# 450665                     NaN
# 450666               /m/02w7gg
# 450667                     NaN
# 450668                     NaN
#
# [450669 rows x 21 columns]

# %%
# add column that contains the number of actors in every movie
# count number of actors in the movie
df_number_actor = df.groupby('wiki_movie_id')[['a_name']].count()
# transform datatype of the column from integer to object
df_number_actor['a_name'] = df_number_actor['a_name'].apply(str)
# rename the column accordingly
df_number_actor = df_number_actor.rename(columns={'a_name': 'number_actors'})
print(df_number_actor.head())
# merge df and df_number_actor by wiki_movie_id (wiki_movie_id = column of df; wiki_movie_id = index of df_number_actor)
df = df.merge(df_number_actor, left_on='wiki_movie_id', right_index=True)
# Out:
#               number_actors
# wiki_movie_id
# 330                       4
# 3217                     14
# 3333                     14
# 3746                     15
# 3837                     20

# %%
# print df with the new column that contains the number of actors
print(df.shape)
df.head()
# Out:
# (450669, 22)
#    wiki_movie_id freebase_movie_id      movie_name release_date  \
# 0         975900         /m/03vyhn  Ghosts of Mars   2001-08-24
# 1         975900         /m/03vyhn  Ghosts of Mars   2001-08-24
# 2         975900         /m/03vyhn  Ghosts of Mars   2001-08-24
# 3         975900         /m/03vyhn  Ghosts of Mars   2001-08-24
# 4         975900         /m/03vyhn  Ghosts of Mars   2001-08-24
#
#    box_office_revenue  runtime  \
# 0          14010832.0     98.0
# 1          14010832.0     98.0
# 2          14010832.0     98.0
# 3          14010832.0     98.0
# 4          14010832.0     98.0
#
#                                               genres  \
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 2  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 3  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 4  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
#
#                             languages  \
# 0  {"/m/02h40lc": "English Language"}
# 1  {"/m/02h40lc": "English Language"}
# 2  {"/m/02h40lc": "English Language"}
# 3  {"/m/02h40lc": "English Language"}
# 4  {"/m/02h40lc": "English Language"}
#
#                                    countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2  {"/m/09c7w0": "United States of America"}
# 3  {"/m/09c7w0": "United States of America"}
# 4  {"/m/09c7w0": "United States of America"}
#
#                                                 plot  \
# 0  Set in the second half of the 22nd century, th...
# 1  Set in the second half of the 22nd century, th...
# 2  Set in the second half of the 22nd century, th...
# 3  Set in the second half of the 22nd century, th...
# 4  Set in the second half of the 22nd century, th...
#
#                     char_name              a_name a_gender        a_ethnicity  \
# 0                    Akooshay      Wanda De Jesus        F                NaN
# 1  Lieutenant Melanie Ballard  Natasha Henstridge        F                NaN
# 2         Desolation Williams            Ice Cube        M  African Americans
# 3          Sgt Jericho Butler       Jason Statham        M                NaN
# 4             Bashira Kincaid         Clea DuVall        F                NaN
#
#         a_dob  a_age_at_release  a_height freebase_char/a_map  \
# 0  1958-08-26              42.0     1.620          /m/0bgchxw
# 1  1974-08-15              27.0     1.780           /m/0jys3m
# 2  1969-06-15              32.0     1.727           /m/0jys3g
# 3  1967-09-12              33.0     1.750          /m/02vchl6
# 4  1977-09-25              23.0     1.650          /m/02vbb3r
#
#   freebase_char_id freebase_a_id a_ethnicity_freebase_id number_actors
# 0       /m/0bgcj3x    /m/03wcfv7                     NaN            17
# 1       /m/0bgchn4     /m/0346l4              /m/044038p            17
# 2       /m/0bgchn_    /m/01vw26l                 /m/0x67            17
# 3       /m/0bgchnq     /m/034hyc                     NaN            17
# 4       /m/0bgchp9     /m/01y9xg                     NaN            17
