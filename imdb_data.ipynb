# %% [markdown]
# # IMDB dataset analysis

# %%
DATA_FOLDER = './data/'
MOVIES_FOLDER = DATA_FOLDER + 'movies_summaries/'
PLOT_SUMMARY_FOLDER = DATA_FOLDER + 'corenlp_plot_summaries'
IMDB_FOLDER = DATA_FOLDER + 'imdb/'

REPORT_FOLDER = './gen/reports/'
ETHNICITY_FILE = './gen/ethnicities.tsv'

CHARACTERS_FILE = MOVIES_FOLDER + 'character.metadata.tsv'
MOVIES_FILE = MOVIES_FOLDER + 'movie.metadata.tsv'
PLOT_SUMMARIES_FILE = MOVIES_FOLDER + 'plot_summaries.txt'
TROPES_FILE = MOVIES_FOLDER + 'tvtropes.clusters.txt'

IMDB_FILE = IMDB_FOLDER + 'movies_metadata.csv'
EUROPEAN_COUNTRIES_FILE = DATA_FOLDER + 'european_countries.txt'

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

from data_wrangling_tools import *

# %%
# import imdb dataset

def load_imdb(imdb_file, columns=['original_title', 'revenue', 'budget', 'vote_average', 'vote_count']):
    imdb = pd.read_csv(imdb_file, usecols=columns)

    # remove wrongly formatted rows (only 3)
    imdb = imdb.drop(imdb[imdb['budget'].str.contains('.jpg')].index)

    # convert numerical columns to float
    imdb['revenue'] = imdb['revenue'].astype(float).apply(lambda x: np.nan if x == 0.0 else x)
    imdb['budget'] = imdb['budget'].astype(float).apply(lambda x: np.nan if x == 0.0 else x)

    return imdb

imdb = load_imdb(IMDB_FILE)
print(imdb.shape)
imdb.head()
# Out:
# (45463, 5)
#        budget               original_title      revenue  vote_average  \
# 0  30000000.0                    Toy Story  373554033.0           7.7
# 1  65000000.0                      Jumanji  262797249.0           6.9
# 2         NaN             Grumpier Old Men          NaN           6.5
# 3  16000000.0            Waiting to Exhale   81452156.0           6.1
# 4         NaN  Father of the Bride Part II   76578911.0           5.7
#
#    vote_count
# 0      5415.0
# 1      2413.0
# 2        92.0
# 3        34.0
# 4       173.0

# %%
# load movies
movies = load_movies(MOVIES_FILE)
movies = clean_unknowns(movies)
movies = clean_jsons(movies)
print(movies.shape)
movies.head()
# Out:
# (81741, 9)
#    wiki_movie_id freebase_movie_id  \
# 0         975900         /m/03vyhn
# 1        3196793         /m/08yl5d
# 2       28463795        /m/0crgdbh
# 3        9363483        /m/0285_cd
# 4         261236         /m/01mrr1
#
#                                                 name release_date  \
# 0                                     Ghosts of Mars   2001-08-24
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                        Brun bitter   1988-01-01
# 3                                   White Of The Eye   1987-01-01
# 4                                  A Woman in Flames   1983-01-01
#
#    box_office_revenue  runtime             languages  \
# 0          14010832.0     98.0    [English Language]
# 1                 NaN     95.0    [English Language]
# 2                 NaN     83.0  [Norwegian Language]
# 3                 NaN    110.0    [English Language]
# 4                 NaN    106.0     [German Language]
#
#                     countries  \
# 0  [United States of America]
# 1  [United States of America]
# 2                    [Norway]
# 3            [United Kingdom]
# 4                   [Germany]
#
#                                               genres
# 0  [Thriller, Science Fiction, Horror, Adventure,...
# 1   [Mystery, Biographical film, Drama, Crime Drama]
# 2                             [Crime Fiction, Drama]
# 3  [Thriller, Erotic thriller, Psychological thri...
# 4                                            [Drama]

# %%
# merge movies and imdb movies

def merge_movies_imdb(movies, imdb):
    df = pd.merge(movies, imdb, left_on='name', right_on='original_title', how='left')

    # drop movies that have been duplicated during the merge TODO see it
    df = df.drop_duplicates(subset=['name', 'vote_count', 'vote_average'])

    # fill the box_office revenue with the imdb revenue if it's missing
    df['box_office_revenue'] = df['box_office_revenue'].fillna(df['revenue'].copy())
    df = df.drop(columns=['revenue', 'original_title'])

    return df

df = merge_movies_imdb(movies, imdb)

print(df.shape)
df.head()
# Out:
# (77380, 12)
#    wiki_movie_id freebase_movie_id  \
# 0         975900         /m/03vyhn
# 1        3196793         /m/08yl5d
# 2       28463795        /m/0crgdbh
# 3        9363483        /m/0285_cd
# 4         261236         /m/01mrr1
#
#                                                 name release_date  \
# 0                                     Ghosts of Mars   2001-08-24
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                        Brun bitter   1988-01-01
# 3                                   White Of The Eye   1987-01-01
# 4                                  A Woman in Flames   1983-01-01
#
#    box_office_revenue  runtime             languages  \
# 0          14010832.0     98.0    [English Language]
# 1                 NaN     95.0    [English Language]
# 2                 NaN     83.0  [Norwegian Language]
# 3                 NaN    110.0    [English Language]
# 4                 NaN    106.0     [German Language]
#
#                     countries  \
# 0  [United States of America]
# 1  [United States of America]
# 2                    [Norway]
# 3            [United Kingdom]
# 4                   [Germany]
#
#                                               genres      budget  \
# 0  [Thriller, Science Fiction, Horror, Adventure,...  28000000.0
# 1   [Mystery, Biographical film, Drama, Crime Drama]         NaN
# 2                             [Crime Fiction, Drama]         NaN
# 3  [Thriller, Erotic thriller, Psychological thri...         NaN
# 4                                            [Drama]         NaN
#
#    vote_average  vote_count
# 0           4.8       299.0
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN

# %% [markdown]
# # Gen the main dataset

# %%
# load characters
characters = load_characters(CHARACTERS_FILE)
ethnicities = load_ethnicities(ETHNICITY_FILE)
characters = add_characters_ethnicities(characters, ethnicities)

# %%
# merge characters and movies
merged_df = merge_characters_movies(characters, df)
merged_df
# Out:
#         wiki_movie_id freebase_movie_id  \
# 0              975900         /m/03vyhn
# 1              975900         /m/03vyhn
# 2              975900         /m/03vyhn
# 3              975900         /m/03vyhn
# 4              975900         /m/03vyhn
# ...               ...               ...
# 467184         913762         /m/03pcrp
# 467185         913762         /m/03pcrp
# 467186       28308153        /m/0cp05t9
# 467187       28308153        /m/0cp05t9
# 467188       28308153        /m/0cp05t9
#
#                                                movie_name release_date  \
# 0                                          Ghosts of Mars   2001-08-24
# 1                                          Ghosts of Mars   2001-08-24
# 2                                          Ghosts of Mars   2001-08-24
# 3                                          Ghosts of Mars   2001-08-24
# 4                                          Ghosts of Mars   2001-08-24
# ...                                                   ...          ...
# 467184  The Super Dimension Fortress Macross II: Lover...   1992-05-21
# 467185  The Super Dimension Fortress Macross II: Lover...   1992-05-21
# 467186                              Five Clues to Fortune   1957-01-01
# 467187                              Five Clues to Fortune   1957-01-01
# 467188                              Five Clues to Fortune   1957-01-01
#
#         box_office_revenue  runtime  \
# 0               14010832.0     98.0
# 1               14010832.0     98.0
# 2               14010832.0     98.0
# 3               14010832.0     98.0
# 4               14010832.0     98.0
# ...                    ...      ...
# 467184                 NaN    150.0
# 467185                 NaN    150.0
# 467186                 NaN    129.0
# 467187                 NaN    129.0
# 467188                 NaN    129.0
#
#                                                    genres  \
# 0       [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Thriller, Science Fiction, Horror, Adventure,...
# 2       [Thriller, Science Fiction, Horror, Adventure,...
# 3       [Thriller, Science Fiction, Horror, Adventure,...
# 4       [Thriller, Science Fiction, Horror, Adventure,...
# ...                                                   ...
# 467184  [Science Fiction, Japanese Movies, Adventure, ...
# 467185  [Science Fiction, Japanese Movies, Adventure, ...
# 467186                                    [Crime Fiction]
# 467187                                    [Crime Fiction]
# 467188                                    [Crime Fiction]
#
#                   languages                   countries  \
# 0        [English Language]  [United States of America]
# 1        [English Language]  [United States of America]
# 2        [English Language]  [United States of America]
# 3        [English Language]  [United States of America]
# 4        [English Language]  [United States of America]
# ...                     ...                         ...
# 467184  [Japanese Language]                     [Japan]
# 467185  [Japanese Language]                     [Japan]
# 467186   [English Language]            [United Kingdom]
# 467187   [English Language]            [United Kingdom]
# 467188   [English Language]            [United Kingdom]
#
#                          char_name              a_name a_gender  \
# 0                         Akooshay      Wanda De Jesus        F
# 1       Lieutenant Melanie Ballard  Natasha Henstridge        F
# 2              Desolation Williams            Ice Cube        M
# 3               Sgt Jericho Butler       Jason Statham        M
# 4                  Bashira Kincaid         Clea DuVall        F
# ...                            ...                 ...      ...
# 467184                      Elensh  Dorothy Elias-Fahn        F
# 467185                      Hibiki       Jonathan Fahn        M
# 467186                         NaN      David Hemmings        M
# 467187                         NaN    Roberta Paterson      NaN
# 467188                         NaN         John Rogers      NaN
#
#               a_ethnicity       a_dob  a_age_at_release  a_height  \
# 0                     NaN  1958-08-26              42.0     1.620
# 1                     NaN  1974-08-15              27.0     1.780
# 2       African Americans  1969-06-15              32.0     1.727
# 3                     NaN  1967-09-12              33.0     1.750
# 4                     NaN  1977-09-25              23.0     1.650
# ...                   ...         ...               ...       ...
# 467184                NaN     1970-05               NaN       NaN
# 467185                NaN  1965-04-12              27.0       NaN
# 467186     English people  1941-11-18              15.0     1.730
# 467187                NaN         NaN               NaN       NaN
# 467188                NaN         NaN               NaN       NaN
#
#        freebase_char/a_map freebase_char_id freebase_a_id  \
# 0               /m/0bgchxw       /m/0bgcj3x    /m/03wcfv7
# 1                /m/0jys3m       /m/0bgchn4     /m/0346l4
# 2                /m/0jys3g       /m/0bgchn_    /m/01vw26l
# 3               /m/02vchl6       /m/0bgchnq     /m/034hyc
# 4               /m/02vbb3r       /m/0bgchp9     /m/01y9xg
# ...                    ...              ...           ...
# 467184          /m/0kr406c       /m/0kr406h     /m/0b_vcv
# 467185          /m/0kr405_       /m/0kr4090     /m/0bx7_j
# 467186          /m/0g8ngmc              NaN     /m/022g44
# 467187          /m/0g8ngmj              NaN    /m/0g8ngmm
# 467188          /m/0g8ngmw              NaN    /m/0btz19d
#
#        a_ethnicity_freebase_id
# 0                          NaN
# 1                   /m/044038p
# 2                      /m/0x67
# 3                          NaN
# 4                          NaN
# ...                        ...
# 467184                     NaN
# 467185                     NaN
# 467186               /m/02w7gg
# 467187                     NaN
# 467188                     NaN
#
# [467189 rows x 20 columns]

# %%
european_countries = pd.read_csv(EUROPEAN_COUNTRIES_FILE, header=None, skiprows=1, names=['country'])['country'].to_list()
